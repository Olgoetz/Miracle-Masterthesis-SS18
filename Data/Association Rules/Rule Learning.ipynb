# %% [markdown]
# # Application of Association Rule Learning
#
# This notebook show how to build association rules and is structured as follows:
# _______

# %% [markdown]
# **1. Import libraries and dataset**
#
# The code blocks import the necessary standard librariers and the data from the datasource.
#
# **2. Extend the finance_data by new column 'Kind of financial products'**
#
# In this section each column entry is put into an array and then added as extra column to the whole dataframe. It is a necessary step to make the association rule algorithm work. It is a kind of preprocessing step.
#
# **3. Apply the association rule learning algorithm**
#
# The section consists of two subsections:
#
# *3.1 Preprocess the data*:
#
# Data is being standardized. The apriori algorithm is responsibel for finding frequent the item sets that frequently appear which is a precondition for deriving rules.
#
# *3.2 Finde the rules*:
#
# By setting appropriate metrics such as 'confidence' with a minimal threshold, rules can be extraced.
#
# **4. Export the new data**
#
# The codeblock exports the found rules as an excel sheet.

# %% [markdown]
# ## 1. Import libraries and dataset

# %%
# import data analysis libaries
import pandas as pd

# import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
# %matplotlib inline

# %%
# provide the data source --> must be an excel
dataset = '../Datasource/data_financeproducts.xlsx'
finance_data = pd.read_excel(dataset )
finance_data.head()
# Out:
#     Sex  Age   Net income  Amount of financial products Stocks  \
# 0  male   28  1250-1499 €                             3     no
# 1  male   56  5000-5999 €                             1     no
# 2  male   28  1250-1499 €                             3     no
# 3  male   29  2000-2499 €                             3     no
# 4  male   29  2000-2499 €                             2     no
#
#   Investment fonds Bond issues Savings certificate Giro account  \
# 0               no          no                  no          yes
# 1               no          no                  no           no
# 2               no          no                  no          yes
# 3               no          no                  no          yes
# 4               no          no                  no          yes
#
#   Day-to-day money account Credit card Fixed deposit account Life insurance  \
# 0                      yes         yes                    no             no
# 1                       no         yes                    no             no
# 2                      yes         yes                    no             no
# 3                       no         yes                    no             no
# 4                       no         yes                    no             no
#
#   Riester pension Housing saving
# 0              no             no
# 1              no             no
# 2              no             no
# 3              no            yes
# 4              no             no

# %%
# non financial columns are removed
finance_data = finance_data.drop(['Sex', 'Age', 'Net income', 'Amount of financial products'], axis = 1)
finance_data.head()
# Out:
#   Stocks Investment fonds Bond issues Savings certificate Giro account  \
# 0     no               no          no                  no          yes
# 1     no               no          no                  no           no
# 2     no               no          no                  no          yes
# 3     no               no          no                  no          yes
# 4     no               no          no                  no          yes
#
#   Day-to-day money account Credit card Fixed deposit account Life insurance  \
# 0                      yes         yes                    no             no
# 1                       no         yes                    no             no
# 2                      yes         yes                    no             no
# 3                       no         yes                    no             no
# 4                       no         yes                    no             no
#
#   Riester pension Housing saving
# 0              no             no
# 1              no             no
# 2              no             no
# 3              no            yes
# 4              no             no

# %% [markdown]
# ## 2. Extend the finance_data by new column 'Kind of financial products'

# %%
# array of items for conditional comparison
items = ['Stocks', 'Investment fonds', 'Bond issues', 'Savings certificate', 'Day-to-day money account', 
         'Fixed deposit account', 'Life insurance', 'Credit card', 'Giro account',
        'Riester pension', 'Housing saving']

# initialize an array for products which will be a new colung in finance_data
products = []

# iterate over all rows in finance_data
for index, row in finance_data.iterrows():
    
    # initialize an array for each row to capture chosen products 
    individual_item_set = []
    
    #iterate over all items and check if an item was chosen
    for pro in items:
        if row[pro]=='yes':
            individual_item_set.append(pro)
    
    # extend the products array with individual_item_set 
    products.append(individual_item_set)

# assign a new column to finance_data
finance_data['Kind of financial products'] = products


# save the new data depending on the 'save' flag
save = False
if save==True:
    finance_data.to_excel('data_financeproducts_final.xlsx')
products
# Out:
# [['Day-to-day money account', 'Credit card', 'Giro account'],
#  ['Credit card'],
#  ['Day-to-day money account', 'Credit card', 'Giro account'],
#  ['Credit card', 'Giro account', 'Housing saving'],
#  ['Credit card', 'Giro account'],
#  ['Credit card', 'Giro account', 'Riester pension'],
#  ['Stocks',
#   'Day-to-day money account',
#   'Fixed deposit account',
#   'Credit card',
#   'Giro account',
#   'Housing saving'],
#  ['Giro account'],
#  ['Giro account'],
#  ['Stocks',
#   'Investment fonds',
#   'Savings certificate',
#   'Day-to-day money account',
#   'Fixed deposit account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Riester pension'],
#  ['Investment fonds',
#   'Day-to-day money account',
#   'Life insurance',
#   'Credit card',
#   'Giro account'],
#  ['Life insurance', 'Credit card', 'Giro account'],
#  ['Credit card', 'Giro account', 'Housing saving'],
#  ['Day-to-day money account',
#   'Fixed deposit account',
#   'Credit card',
#   'Giro account'],
#  ['Investment fonds', 'Credit card', 'Giro account', 'Riester pension'],
#  ['Giro account'],
#  ['Giro account', 'Housing saving'],
#  ['Stocks', 'Credit card', 'Giro account', 'Riester pension'],
#  ['Life insurance', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Day-to-day money account',
#   'Fixed deposit account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Riester pension'],
#  ['Giro account'],
#  ['Bond issues'],
#  ['Bond issues', 'Savings certificate', 'Giro account', 'Housing saving'],
#  ['Day-to-day money account', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Credit card', 'Giro account'],
#  ['Investment fonds',
#   'Day-to-day money account',
#   'Credit card',
#   'Giro account'],
#  ['Day-to-day money account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Riester pension'],
#  ['Investment fonds', 'Life insurance', 'Credit card', 'Giro account'],
#  ['Stocks', 'Bond issues', 'Credit card', 'Giro account'],
#  ['Savings certificate', 'Giro account'],
#  ['Savings certificate', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Credit card', 'Giro account'],
#  ['Day-to-day money account', 'Credit card', 'Giro account'],
#  ['Stocks',
#   'Savings certificate',
#   'Fixed deposit account',
#   'Credit card',
#   'Giro account',
#   'Riester pension',
#   'Housing saving'],
#  ['Life insurance',
#   'Credit card',
#   'Giro account',
#   'Riester pension',
#   'Housing saving'],
#  ['Life insurance', 'Giro account', 'Housing saving'],
#  ['Giro account'],
#  ['Stocks', 'Bond issues', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Credit card', 'Giro account', 'Riester pension', 'Housing saving'],
#  ['Giro account'],
#  ['Stocks', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Fixed deposit account', 'Life insurance', 'Giro account', 'Housing saving'],
#  ['Life insurance', 'Credit card', 'Giro account'],
#  ['Giro account'],
#  ['Credit card', 'Giro account', 'Riester pension'],
#  ['Day-to-day money account', 'Life insurance', 'Credit card', 'Giro account'],
#  ['Stocks',
#   'Day-to-day money account',
#   'Fixed deposit account',
#   'Credit card',
#   'Giro account',
#   'Riester pension'],
#  ['Day-to-day money account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Riester pension'],
#  ['Life insurance', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Fixed deposit account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Housing saving'],
#  ['Life insurance', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Life insurance', 'Credit card', 'Housing saving'],
#  ['Investment fonds',
#   'Day-to-day money account',
#   'Credit card',
#   'Giro account',
#   'Riester pension'],
#  ['Day-to-day money account', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Investment fonds',
#   'Day-to-day money account',
#   'Fixed deposit account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Housing saving'],
#  ['Giro account'],
#  ['Day-to-day money account', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Savings certificate', 'Credit card', 'Giro account'],
#  ['Stocks',
#   'Day-to-day money account',
#   'Credit card',
#   'Giro account',
#   'Housing saving'],
#  ['Credit card', 'Giro account'],
#  ['Day-to-day money account',
#   'Fixed deposit account',
#   'Credit card',
#   'Giro account'],
#  ['Stocks', 'Savings certificate', 'Credit card', 'Giro account'],
#  ['Day-to-day money account',
#   'Credit card',
#   'Giro account',
#   'Riester pension',
#   'Housing saving'],
#  ['Investment fonds'],
#  ['Investment fonds', 'Credit card', 'Giro account'],
#  ['Credit card', 'Giro account'],
#  ['Credit card', 'Giro account'],
#  ['Stocks',
#   'Fixed deposit account',
#   'Life insurance',
#   'Credit card',
#   'Riester pension'],
#  ['Stocks', 'Day-to-day money account', 'Life insurance', 'Credit card'],
#  ['Day-to-day money account', 'Giro account'],
#  ['Stocks', 'Investment fonds', 'Giro account', 'Housing saving'],
#  ['Credit card'],
#  ['Life insurance', 'Giro account', 'Housing saving'],
#  ['Stocks',
#   'Investment fonds',
#   'Day-to-day money account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Housing saving'],
#  ['Investment fonds',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Housing saving'],
#  ['Investment fonds',
#   'Day-to-day money account',
#   'Credit card',
#   'Giro account'],
#  ['Credit card', 'Giro account'],
#  ['Day-to-day money account',
#   'Fixed deposit account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Riester pension'],
#  ['Bond issues', 'Credit card'],
#  ['Life insurance', 'Giro account', 'Housing saving'],
#  ['Investment fonds',
#   'Day-to-day money account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Riester pension'],
#  ['Stocks', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Life insurance', 'Credit card', 'Giro account', 'Riester pension'],
#  ['Day-to-day money account',
#   'Fixed deposit account',
#   'Life insurance',
#   'Credit card',
#   'Giro account'],
#  ['Savings certificate', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Credit card', 'Giro account', 'Housing saving'],
#  ['Investment fonds', 'Fixed deposit account', 'Credit card', 'Giro account'],
#  ['Savings certificate',
#   'Day-to-day money account',
#   'Fixed deposit account',
#   'Credit card',
#   'Giro account',
#   'Riester pension'],
#  ['Stocks',
#   'Savings certificate',
#   'Day-to-day money account',
#   'Fixed deposit account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Housing saving'],
#  ['Stocks', 'Day-to-day money account', 'Credit card', 'Giro account'],
#  ['Stocks',
#   'Day-to-day money account',
#   'Credit card',
#   'Giro account',
#   'Housing saving'],
#  ['Savings certificate',
#   'Fixed deposit account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Riester pension',
#   'Housing saving'],
#  ['Housing saving'],
#  ['Life insurance', 'Giro account', 'Riester pension', 'Housing saving'],
#  ['Stocks',
#   'Day-to-day money account',
#   'Fixed deposit account',
#   'Credit card',
#   'Giro account'],
#  ['Stocks', 'Credit card', 'Giro account'],
#  ['Housing saving'],
#  ['Credit card', 'Giro account'],
#  ['Fixed deposit account', 'Credit card', 'Giro account'],
#  ['Credit card', 'Giro account'],
#  ['Credit card', 'Giro account'],
#  ['Life insurance', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Giro account', 'Riester pension'],
#  ['Credit card', 'Giro account'],
#  ['Giro account', 'Housing saving'],
#  ['Investment fonds',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Housing saving'],
#  ['Day-to-day money account', 'Credit card', 'Giro account'],
#  ['Stocks', 'Day-to-day money account', 'Credit card', 'Giro account'],
#  ['Credit card', 'Giro account', 'Housing saving'],
#  ['Credit card', 'Giro account'],
#  ['Investment fonds',
#   'Day-to-day money account',
#   'Life insurance',
#   'Credit card',
#   'Giro account'],
#  ['Day-to-day money account', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Life insurance', 'Giro account', 'Riester pension'],
#  ['Day-to-day money account', 'Credit card', 'Giro account'],
#  ['Day-to-day money account',
#   'Fixed deposit account',
#   'Credit card',
#   'Giro account'],
#  ['Day-to-day money account', 'Credit card', 'Giro account'],
#  ['Stocks', 'Day-to-day money account', 'Credit card', 'Giro account'],
#  ['Giro account'],
#  ['Life insurance', 'Credit card', 'Giro account'],
#  ['Credit card', 'Giro account'],
#  ['Day-to-day money account', 'Life insurance', 'Credit card', 'Giro account'],
#  ['Investment fonds', 'Savings certificate', 'Life insurance', 'Giro account'],
#  ['Investment fonds',
#   'Day-to-day money account',
#   'Credit card',
#   'Giro account',
#   'Riester pension',
#   'Housing saving'],
#  ['Fixed deposit account', 'Credit card', 'Giro account'],
#  ['Day-to-day money account', 'Credit card', 'Giro account', 'Housing saving'],
#  ['Day-to-day money account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Housing saving'],
#  ['Credit card', 'Housing saving'],
#  ['Investment fonds',
#   'Fixed deposit account',
#   'Life insurance',
#   'Credit card'],
#  ['Day-to-day money account', 'Life insurance', 'Credit card', 'Giro account'],
#  ['Investment fonds',
#   'Day-to-day money account',
#   'Fixed deposit account',
#   'Life insurance',
#   'Credit card',
#   'Giro account',
#   'Housing saving']]

# %%
# transform the itemsets into the correct format for the upcoming 
# applicaton of the apriori algorithm

# assign the column 'Kind of financial products' to a variable
items = finance_data['Kind of financial products']

# generate an array
analysis = []

# add each itemset as array to a new array containing all itemsets
for item in items.iteritems():
    if (len(item[1]) != 0):
        analysis.append(item[1])

# %% [markdown]
# ## 3. Apply the association rule learning algorithm

# %% [markdown]
# ### 3.1 Preprocess the data

# %%
# import rule learning preprocessing libraries
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# transform the data respectively standardize them
transactionencoder = TransactionEncoder()
transactionencoder_ary = transactionencoder.fit(analysis).transform(analysis)

# assign the encoded data to a new DataFrame and find unique names for column description
df = pd.DataFrame(transactionencoder_ary, columns=transactionencoder.columns_)

# find itemsets with the apriori algorithm
support = 0.15
frequent_itemsets = apriori(df, min_support=support, use_colnames=True)
frequent_itemsets
# Out:
#      support                                           itemsets
# 0   0.792308                                      [Credit card]
# 1   0.361538                         [Day-to-day money account]
# 2   0.176923                            [Fixed deposit account]
# 3   0.907692                                     [Giro account]
# 4   0.369231                                   [Housing saving]
# 5   0.161538                                 [Investment fonds]
# 6   0.323077                                   [Life insurance]
# 7   0.184615                                  [Riester pension]
# 8   0.169231                                           [Stocks]
# 9   0.353846            [Credit card, Day-to-day money account]
# 10  0.169231               [Credit card, Fixed deposit account]
# 11  0.730769                        [Credit card, Giro account]
# 12  0.284615                      [Credit card, Housing saving]
# 13  0.269231                      [Credit card, Life insurance]
# 14  0.161538                     [Credit card, Riester pension]
# 15  0.161538                              [Credit card, Stocks]
# 16  0.353846           [Day-to-day money account, Giro account]
# 17  0.161538              [Fixed deposit account, Giro account]
# 18  0.338462                     [Giro account, Housing saving]
# 19  0.292308                     [Giro account, Life insurance]
# 20  0.176923                    [Giro account, Riester pension]
# 21  0.153846                             [Giro account, Stocks]
# 22  0.153846                   [Housing saving, Life insurance]
# 23  0.346154  [Credit card, Day-to-day money account, Giro a...
# 24  0.153846  [Credit card, Fixed deposit account, Giro acco...
# 25  0.269231        [Credit card, Giro account, Housing saving]
# 26  0.238462        [Credit card, Giro account, Life insurance]
# 27  0.153846       [Credit card, Giro account, Riester pension]

# %% [markdown]
# ### 3.2 Find the rules

# %%
# import rule learning library
from mlxtend.frequent_patterns import association_rules

# find rules with a defined metric and a minimum of threshold
rules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)
rules
# Out:
#                                  antecedants  \
# 0                 (Day-to-day money account)
# 1                              (Credit card)
# 2                    (Fixed deposit account)
# 3                              (Credit card)
# 4                             (Giro account)
# 5                           (Housing saving)
# 6                           (Life insurance)
# 7                          (Riester pension)
# 8                                   (Stocks)
# 9                 (Day-to-day money account)
# 10                   (Fixed deposit account)
# 11                          (Housing saving)
# 12                          (Life insurance)
# 13                         (Riester pension)
# 14                                  (Stocks)
# 15                          (Life insurance)
# 16                          (Housing saving)
# 17   (Day-to-day money account, Credit card)
# 18  (Day-to-day money account, Giro account)
# 19               (Credit card, Giro account)
# 20                (Day-to-day money account)
# 21                             (Credit card)
# 22      (Credit card, Fixed deposit account)
# 23     (Giro account, Fixed deposit account)
# 24                   (Fixed deposit account)
# 25             (Credit card, Housing saving)
# 26            (Housing saving, Giro account)
# 27                          (Housing saving)
# 28             (Life insurance, Credit card)
# 29            (Life insurance, Giro account)
# 30                          (Life insurance)
# 31            (Riester pension, Credit card)
# 32           (Riester pension, Giro account)
# 33                         (Riester pension)
#
#                                  consequents  antecedent support  \
# 0                              (Credit card)            0.361538
# 1                 (Day-to-day money account)            0.792308
# 2                              (Credit card)            0.176923
# 3                             (Giro account)            0.792308
# 4                              (Credit card)            0.907692
# 5                              (Credit card)            0.369231
# 6                              (Credit card)            0.323077
# 7                              (Credit card)            0.184615
# 8                              (Credit card)            0.169231
# 9                             (Giro account)            0.361538
# 10                            (Giro account)            0.176923
# 11                            (Giro account)            0.369231
# 12                            (Giro account)            0.323077
# 13                            (Giro account)            0.184615
# 14                            (Giro account)            0.169231
# 15                          (Housing saving)            0.323077
# 16                          (Life insurance)            0.369231
# 17                            (Giro account)            0.353846
# 18                             (Credit card)            0.353846
# 19                (Day-to-day money account)            0.730769
# 20               (Credit card, Giro account)            0.361538
# 21  (Day-to-day money account, Giro account)            0.792308
# 22                            (Giro account)            0.169231
# 23                             (Credit card)            0.161538
# 24               (Credit card, Giro account)            0.176923
# 25                            (Giro account)            0.284615
# 26                             (Credit card)            0.338462
# 27               (Credit card, Giro account)            0.369231
# 28                            (Giro account)            0.269231
# 29                             (Credit card)            0.292308
# 30               (Credit card, Giro account)            0.323077
# 31                            (Giro account)            0.161538
# 32                             (Credit card)            0.176923
# 33               (Credit card, Giro account)            0.184615
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.792308  0.353846    0.978723  1.235282  0.067396    9.761538
# 1             0.361538  0.353846    0.446602  1.235282  0.067396    1.153711
# 2             0.792308  0.169231    0.956522  1.207260  0.029053    4.776923
# 3             0.907692  0.730769    0.922330  1.016126  0.011598    1.188462
# 4             0.792308  0.730769    0.805085  1.016126  0.011598    1.065552
# 5             0.792308  0.284615    0.770833  0.972896 -0.007929    0.906294
# 6             0.792308  0.269231    0.833333  1.051780  0.013254    1.246154
# 7             0.792308  0.161538    0.875000  1.104369  0.015266    1.661538
# 8             0.792308  0.161538    0.954545  1.204766  0.027456    4.569231
# 9             0.907692  0.353846    0.978723  1.078255  0.025680    4.338462
# 10            0.907692  0.161538    0.913043  1.005895  0.000947    1.061538
# 11            0.907692  0.338462    0.916667  1.009887  0.003314    1.107692
# 12            0.907692  0.292308    0.904762  0.996772 -0.000947    0.969231
# 13            0.907692  0.176923    0.958333  1.055791  0.009349    2.215385
# 14            0.907692  0.153846    0.909091  1.001541  0.000237    1.015385
# 15            0.369231  0.153846    0.476190  1.289683  0.034556    1.204196
# 16            0.323077  0.153846    0.416667  1.289683  0.034556    1.160440
# 17            0.907692  0.346154    0.978261  1.077745  0.024970    4.246154
# 18            0.792308  0.346154    0.978261  1.234698  0.065799    9.553846
# 19            0.361538  0.346154    0.473684  1.310190  0.081953    1.213077
# 20            0.730769  0.346154    0.957447  1.310190  0.081953    6.326923
# 21            0.353846  0.346154    0.436893  1.234698  0.065799    1.147480
# 22            0.907692  0.153846    0.909091  1.001541  0.000237    1.015385
# 23            0.792308  0.153846    0.952381  1.202034  0.025858    4.361538
# 24            0.730769  0.153846    0.869565  1.189931  0.024556    2.064103
# 25            0.907692  0.269231    0.945946  1.042144  0.010888    1.707692
# 26            0.792308  0.269231    0.795455  1.003972  0.001065    1.015385
# 27            0.730769  0.269231    0.729167  0.997807 -0.000592    0.994083
# 28            0.907692  0.238462    0.885714  0.975787 -0.005917    0.807692
# 29            0.792308  0.238462    0.815789  1.029637  0.006864    1.127473
# 30            0.730769  0.238462    0.738095  1.010025  0.002367    1.027972
# 31            0.907692  0.153846    0.952381  1.049233  0.007219    1.938462
# 32            0.792308  0.153846    0.869565  1.097509  0.013669    1.592308
# 33            0.730769  0.153846    0.833333  1.140351  0.018935    1.615385

# %% [markdown]
# ## 4. Export the new built dataset

# %%
# export the itemsets and rules into a new files
frequent_itemsets.to_excel("Frequent itemsets.xlsx")
rules.to_excel("Computed association rules.xlsx")
